# %% [markdown]
# ### Práctica de Web Scraping
#
# Se va a considerar un conjunto de páginas web de wikipedia donde se almacena información sobre plantas medicinales:
#
# https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(A-B)
#
# https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(C)
#
# https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(D-G)
#
# https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(H-M)
#
# https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(N-Z)
#
# Cada página tiene una misma estructura. Al principio hay un índice con todas las plantas medicinales que se describen en la página y a continuación se describe la información de cada planta medicinal secuencialmente y en orden alfabético.
#
# __A.  Índice de las plantas de la página:__
#
# https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(A-B)

# %%
from IPython.display import Image
Image(filename='Captura1.png')

# %% [markdown]
# Observar que el índice se encuentra en el código html encerrado por una etiqueta de tipo lista no ordenada __"</ul/>"__

# %%
from IPython.display import Image
Image(filename='Captura2.png')

# %% [markdown]
# __B.Descripción posterior de cada planta de la página:__
#
# https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(A-B)

# %%
from IPython.display import Image
Image(filename='Captura3.png')

# %% [markdown]
# Observar que cada descripción de un planta se encuentra en el código html limitado por una etiqueta de encabezado de tipo  __"</h3/>"__

# %%
from IPython.display import Image
Image(filename='Captura4.png')

# %% [markdown]
# Para recuperar el contenido de cualquiera de las páginas html de wikipedia, se puede hacer de la siguiente manera:

# %%
import requests
url="https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(A-B)"
r = requests.get(url)
html = r.text
print(html)

# %%
for url in webs:
    html=urllib.request.urlopen(url).read()
    soup=BeautifulSoup(html, 'html.parser')
    plantas = soup("h3")
    for planta in plantas:
        print(planta.find_next_siblings('p'), "\n\n")

# %% [markdown]
# Se pide hacer un buscador que permita recuperar información de la página. Para ello se le mostrará al usuario dos opciones entre las que tiene que elegir: Buscar por índice o Buscar por palabra clave.
#
# __Buscar por índice[5 puntos]__
#
# Si elige esta opción se le mostrará un primer listado que muestre 5 opciones:
#
# 1. Plantas medicinales(A-B)
#
# 2. Plantas medicinales(C)
#
# 3. Plantas medicinales(D-G)
#
# 4. Plantas medicinales(H-M)
#
# 5. Plantas medicinales(N-Z)
#
# Cuando seleccione uno de las opciones, le aparecerá otro listado con las plantas medicinales que aparecen en la página asociada a la opción elegida. Por ejemplo si hubiera elegido la opción 1,se mostraría el listado:
#
# 1. Albahaca
# 2. Aceituno
# 3. Agastache
# 4. Ajenjo
# 5. Alcotán
# 6. Manzanilla
# 7. Amargón
# 8. Apacin
# 9. Epazote
# 10. Apio
# 11. Arrayán
# 12. Árnica
# 13. Bacche
# 14. Barbasco
# 15. Bolsa de pastor
# 16. Berro
# 17. Boldo
# 18. Borraja
# 19. Bretónica
# 20. Buganvilea
#
# A continuación cuando seleccione una de las plantas se le mostrará la información asociada a la planta elegida. Por ejemplo si hubiera eleigdo la opción 1, se mostraría la información:
#
# __Planta:__
#
# Albahaca
#
# __Nombre científico:__
#
# Ocimum Basilicum L.
#
# __Descripción:__
#
# Originaria de Persia y Asia Menor, y también mallor comúnmente cultivada en los climas cálidos o fríos, no resiste a temperaturas inferiores a -2°C, la propagación de esta especia se da mediante semillas, en siembra directa la nacencia se inicia a los diez o doce días y se repican cuando tienen de cuatro a seis hojas​.
# Es una planta aromática, medicial, herbácea. La parte útil de la planta medicinal son las ramas y hojas en cualquier estado de desarrollo, se prepara con una bebida hiviendo las partes de la planta en agua o como infusión. Su uso tradicional se realiza para tratar problemas del corazón y de los nervios, las hojas se consumen como antiflatulento.
#
# Por último, se le preguntará al usuario si desea realizar una nueva búsqueda, en caso afirmativo se le mostrará de nuevo el listado inicial, y en caso negativo, finalizará la función.
#
# __Buscar por palabra clave[5 puntos]__
#
# Si elige esta opción se le pedirá al usuario que introduzca un conjunto de palabras que se utilizarán para realizar una búsqueda sobre el texto de las descripciones asociadas a las plantas que aparecen en cada página. A continuación, se ha introducido más de una palabra, se le preguntará si quiere realizar una búsqueda de tipo "AND" o una búsqueda de tipo "OR", es decir si busca plantas donde aparece todas las palabras introducidas o si si busca plantas donde aparecen alguna de las palabras introducidas. Como resultado se le mostrará un listado de todas las plantas junto a las descripciones de las mismas que cumplen las condiciones de búsqueda.
#
# Por último, se le preguntará al usuario si desea realizar una nueva búsqueda, en caso afirmativo se le mostrará de nuevo el listado inicial, y en caso negativo, finalizará la función.
#
# Sugerencias:
# 1. Una opción para gestionar la información es primero leerse todas las páginas extrayendo de cada página  la información de cada página y guardándola en un diccionario donde la clave es el nombre de la planta y el valor es el par (nombre científico, descripción).
#
# 2. Se pueden crear una función de búsqueda de una cadena en un texto dado y que devuelva si la cadena está o no. Así se podría crear un diccionario que tuviera como clave las cadenas buscadas y como valor la lista de los nombres de las plantas que contienen esas cadenas. Cuando se aplica a todas las palabras buscadas, entonces si se quiere una búsqueda "AND" consiste en encontrar la intersección de las listas de nombres de plantas del diccionario y si se quiere una búsqueda "OR" consiste en unir las listas de nombres de plantas del diccionario pero evitando las repeticiones.
#
# __Nota: Para procesar la página html es obligatorio utilizar la libreria BeautifulSoup. No se pueden usar otras librerías no vistas en clase__

# %%
# import urllib
from bs4 import BeautifulSoup
webs = ["https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(A-B)",
        "https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(C)",
        "https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(D-G)",
        "https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(H-M)",
        "https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(N-Z)"]
hrefBreak = ["Notas y referencias","Referencias", "Ver también"]
hrefContinue = ["Usos en medicina herbolaria", "Usos en la alimentación"]
diccionarioPlantas={"https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(A-B)":[],
        "https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(C)":[],
        "https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(D-G)":[],
        "https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(H-M)":[],
        "https://es.wikipedia.org/wiki/Anexo:Plantas_medicinales_(N-Z)":[]}


def devuelvePlantas(url):
    html=urllib.request.urlopen(url).read()
    soup=BeautifulSoup(html, 'html.parser')
    for planta in soup.ul.find_all('a'):
        nombre = planta.get("href",None).lstrip("#").replace("_"," ")
        if nombre in hrefBreak:
            break;
        elif nombre in hrefContinue:
            continue;
        else:
            diccionarioPlantas[url].append(nombre)
    return diccionarioPlantas

def menu():
    opcion = -1
    print("------------------- MENU -------------------")
    print("1. Buscar por índice")
    print("2. Buscar por palabra clave")
    print("0. Salir")
    print("--------------------------------------------\n")
    
    opcion = input("Elige una opción:")
    if opcion.isdigit():
        opcion = int(opcion)
        if(opcion >= 0 and opcion <= 2):
            return int(opcion)
    print("Opción no válida\n")
    return -1

def menuPorIndice():
    opcion = -1
    print("------------------- CRITERIO -------------------")
    print("1. Plantas medicinales(A-B)")
    print("2. Plantas medicinales(C)")
    print("3. Plantas medicinales(D-G)")
    print("4. Plantas medicinales(H-M)")
    print("5. Plantas medicinales(N-Z)")
    print("--------------------------------------------\n")

    opcion = input("Elige una opción (0 para salir):")
    if opcion.isdigit():
        opcion = int(opcion)
        if(opcion > 0 and opcion <= 5):
            return int(opcion)
        elif opcion == 0:
            print("Se termina la búsqueda")
    else:
        print("Opción no válida, se termina la ejecución\n")
    
    return -1


def menuSeleccionPlanta(plantas):
    i = 1
    for planta in plantas:
        print(i, ". ", planta)
        i+=1
    return i-1


def infoPlanta(planta):
    return 0

#-------------------------------------------------------------
opcion = -1
buscar = True
while buscar:
    opcion = menu()
    if (opcion == 0):
        print("Bye!")
        break
    elif(opcion == 1):
        print("Búsqueda por índice\n")
        for url in webs:
            diccionarioPlantas = devuelvePlantas(url)
        for web in diccionarioPlantas:
            #print(diccionarioPlantas[web])
            while buscar:
                opcion = menuPorIndice()
                while (opcion != -1):
                    numPlantas = menuSeleccionPlanta(diccionarioPlantas[webs[opcion-1]])
                    planta = int(input("\nSelecciona una planta: "))
                    if(planta < 1 or planta > numPlantas):
                        print("Planta no válida.")
                    else:
                        print("Informacion de la planta:\n")
                        
                        opcion = -1  
                else:
                    buscar = False
    else:
        print("Búsqueda por palabra clave")
# Out:
# ------------------- MENU -------------------
# 1. Buscar por índice
# 2. Buscar por palabra clave
# 0. Salir
# --------------------------------------------
#
# Elige una opción:1
# Búsqueda por índice
#
# <a href="#Albahaca"><span class="tocnumber">1</span> <span class="toctext"><b>Albahaca</b></span></a>
# Albahaca
# <a href="#Aceituno"><span class="tocnumber">2</span> <span class="toctext">Aceituno</span></a>
# Aceituno
# <a href="#Agastache"><span class="tocnumber">3</span> <span class="toctext">Agastache</span></a>
# Agastache
# <a href="#Ajenjo"><span class="tocnumber">4</span> <span class="toctext">Ajenjo</span></a>
# Ajenjo
# <a href="#Alcotán"><span class="tocnumber">5</span> <span class="toctext">Alcotán</span></a>
# Alcotán
# <a href="#Manzanilla"><span class="tocnumber">6</span> <span class="toctext">Manzanilla</span></a>
# Manzanilla
# <a href="#Amargón"><span class="tocnumber">7</span> <span class="toctext">Amargón</span></a>
# Amargón
# <a href="#Apacin"><span class="tocnumber">8</span> <span class="toctext">Apacin</span></a>
# Apacin
# <a href="#Epazote"><span class="tocnumber">9</span> <span class="toctext">Epazote</span></a>
# Epazote
# <a href="#Apio"><span class="tocnumber">10</span> <span class="toctext">Apio</span></a>
# Apio
# <a href="#Arrayán"><span class="tocnumber">11</span> <span class="toctext">Arrayán</span></a>
# Arrayán
# <a href="#Árnica"><span class="tocnumber">12</span> <span class="toctext">Árnica</span></a>
# Árnica
# <a href="#Bacche"><span class="tocnumber">13</span> <span class="toctext">Bacche</span></a>
# Bacche
# <a href="#Barbasco"><span class="tocnumber">14</span> <span class="toctext">Barbasco</span></a>
# Barbasco
# <a href="#Bolsa_de_pastor"><span class="tocnumber">15</span> <span class="toctext">Bolsa de pastor</span></a>
# Bolsa de pastor
# <a href="#Berro"><span class="tocnumber">16</span> <span class="toctext">Berro</span></a>
# Berro
# <a href="#Boldo"><span class="tocnumber">17</span> <span class="toctext">Boldo</span></a>
# Boldo
# <a href="#Borraja"><span class="tocnumber">18</span> <span class="toctext">Borraja</span></a>
# Borraja
# <a href="#Bretónica"><span class="tocnumber">19</span> <span class="toctext">Bretónica</span></a>
# Bretónica
# <a href="#Buganvilea"><span class="tocnumber">20</span> <span class="toctext">Buganvilea</span></a>
# Buganvilea
# <a href="#Notas_y_referencias"><span class="tocnumber">21</span> <span class="toctext">Notas y referencias</span></a>
# Notas y referencias
# <a href="#Cacao"><span class="tocnumber">1</span> <span class="toctext">Cacao</span></a>
# Cacao
# <a href="#Café"><span class="tocnumber">2</span> <span class="toctext">Café</span></a>
# Café
# <a href="#Calaguala"><span class="tocnumber">3</span> <span class="toctext">Calaguala</span></a>
# Calaguala
# <a href="#Caléndula"><span class="tocnumber">4</span> <span class="toctext">Caléndula</span></a>
# Caléndula
# <a href="#Canayuyo"><span class="tocnumber">5</span> <span class="toctext">Canayuyo</span></a>
# Canayuyo
# <a href="#Canela"><span class="tocnumber">6</span> <span class="toctext">Canela</span></a>
# Canela
# <a href="#Cañafístula"><span class="tocnumber">7</span> <span class="toctext">Cañafístula</span></a>
# Cañafístula
# <a href="#Capulí"><span class="tocnumber">8</span> <span class="toctext">Capulí</span></a>
# Capulí
# <a href="#Carao"><span class="tocnumber">9</span> <span class="toctext">Carao</span></a>
# Carao
# <a href="#Cardamomo"><span class="tocnumber">10</span> <span class="toctext">Cardamomo</span></a>
# Cardamomo
# <a href="#Cardo_de_María"><span class="tocnumber">11</span> <span class="toctext">Cardo de María</span></a>
# Cardo de María
# <a href="#Cardo_santo"><span class="tocnumber">12</span> <span class="toctext">Cardo santo</span></a>
# Cardo santo
# <a href="#Carqueja"><span class="tocnumber">13</span> <span class="toctext">Carqueja</span></a>
# Carqueja
# <a href="#Cáscara_sagrada"><span class="tocnumber">14</span> <span class="toctext">Cáscara sagrada</span></a>
# Cáscara sagrada
# <a href="#Cascarilla"><span class="tocnumber">15</span> <span class="toctext">Cascarilla</span></a>
# Cascarilla
# <a href="#Cashamarucha"><span class="tocnumber">16</span> <span class="toctext">Cashamarucha</span></a>
# Cashamarucha
# <a href="#Caulote"><span class="tocnumber">17</span> <span class="toctext">Caulote</span></a>
# Caulote
# <a href="#Cebada"><span class="tocnumber">18</span> <span class="toctext">Cebada</span></a>
# Cebada
# <a href="#Cebolla"><span class="tocnumber">19</span> <span class="toctext">Cebolla</span></a>
# Cebolla
# <a href="#Cedrón"><span class="tocnumber">20</span> <span class="toctext">Cedrón</span></a>
# Cedrón
# <a href="#Chalchupa"><span class="tocnumber">21</span> <span class="toctext">Chalchupa</span></a>
# Chalchupa
# <a href="#Chichipince"><span class="tocnumber">22</span> <span class="toctext">Chichipince</span></a>
# Chichipince
# <a href="#Chipilín"><span class="tocnumber">23</span> <span class="toctext">Chipilín</span></a>
# Chipilín
# <a href="#Cimicifuga"><span class="tocnumber">24</span> <span class="toctext">Cimicifuga</span></a>
# Cimicifuga
# <a href="#Clavo"><span class="tocnumber">25</span> <span class="toctext">Clavo</span></a>
# Clavo
# <a href="#Cola_de_caballo"><span class="tocnumber">26</span> <span class="toctext">Cola de caballo</span></a>
# Cola de caballo
# <a href="#Copalchi"><span class="tocnumber">27</span> <span class="toctext">Copalchi</span></a>
# Copalchi
# <a href="#Cuasia"><span class="tocnumber">28</span> <span class="toctext">Cuasia</span></a>
# Cuasia
# <a href="#Culantrillo"><span class="tocnumber">29</span> <span class="toctext">Culantrillo</span></a>
# Culantrillo
# <a href="#Culantro"><span class="tocnumber">30</span> <span class="toctext">Culantro</span></a>
# Culantro
# <a href="#Cundeamor"><span class="tocnumber">31</span> <span class="toctext">Cundeamor</span></a>
# Cundeamor
# <a href="#Cúrcuma"><span class="tocnumber">32</span> <span class="toctext">Cúrcuma</span></a>
# Cúrcuma
# <a href="#Ver_también"><span class="tocnumber">33</span> <span class="toctext">Ver también</span></a>
# Ver también
# <a href="#Damiana"><span class="tocnumber">1</span> <span class="toctext">Damiana</span></a>
# Damiana
# <a href="#Diente_de_león"><span class="tocnumber">2</span> <span class="toctext">Diente de león</span></a>
# Diente de león
# <a href="#Digital"><span class="tocnumber">3</span> <span class="toctext">Digital</span></a>
# Digital
# <a href="#Efedra"><span class="tocnumber">4</span> <span class="toctext">Efedra</span></a>
# Efedra
# <a href="#Encino"><span class="tocnumber">5</span> <span class="toctext">Encino</span></a>
# Encino
# <a href="#Esponjuelo"><span class="tocnumber">6</span> <span class="toctext">Esponjuelo</span></a>
# Esponjuelo
# <a href="#Estramonio"><span class="tocnumber">7</span> <span class="toctext">Estramonio</span></a>
# Estramonio
# <a href="#Eucalipto"><span class="tocnumber">8</span> <span class="toctext">Eucalipto</span></a>
# Eucalipto
# <a href="#Fenogreco"><span class="tocnumber">9</span> <span class="toctext">Fenogreco</span></a>
# Fenogreco
# <a href="#Fresa"><span class="tocnumber">10</span> <span class="toctext">Fresa</span></a>
# Fresa
# <a href="#Frijolillo"><span class="tocnumber">11</span> <span class="toctext">Frijolillo</span></a>
# Frijolillo
# <a href="#Garra_del_diablo"><span class="tocnumber">12</span> <span class="toctext">Garra del diablo</span></a>
# Garra del diablo
# <a href="#Ginkgo"><span class="tocnumber">13</span> <span class="toctext">Ginkgo</span></a>
# Ginkgo
# <a href="#Ginseng"><span class="tocnumber">14</span> <span class="toctext">Ginseng</span></a>
# Ginseng
# <a href="#Gordolobo"><span class="tocnumber">15</span> <span class="toctext">Gordolobo</span></a>
# Gordolobo
# <a href="#Granadilla"><span class="tocnumber">16</span> <span class="toctext">Granadilla</span></a>
# Granadilla
# <a href="#Granado"><span class="tocnumber">17</span> <span class="toctext">Granado</span></a>
# Granado
# <a href="#Guachipilin"><span class="tocnumber">18</span> <span class="toctext">Guachipilin</span></a>
# Guachipilin
# <a href="#Guaraná"><span class="tocnumber">19</span> <span class="toctext">Guaraná</span></a>
# Guaraná
# <a href="#Guarumo"><span class="tocnumber">20</span> <span class="toctext">Guarumo</span></a>
# Guarumo
# <a href="#Guayaba"><span class="tocnumber">21</span> <span class="toctext">Guayaba</span></a>
# Guayaba
# <a href="#Güisquil"><span class="tocnumber">22</span> <span class="toctext">Güisquil</span></a>
# Güisquil
# <a href="#Notas_y_referencias"><span class="tocnumber">23</span> <span class="toctext">Notas y referencias</span></a>
# Notas y referencias
# <a href="#Hierba_del_cáncer"><span class="tocnumber">1</span> <span class="toctext">Hierba del cáncer</span></a>
# Hierba del cáncer
# <a href="#Hierba_del_gato"><span class="tocnumber">2</span> <span class="toctext">Hierba del gato</span></a>
# Hierba del gato
# <a href="#Hierba_del_toro"><span class="tocnumber">3</span> <span class="toctext">Hierba del toro</span></a>
# Hierba del toro
# <a href="#Hierba_Luisa"><span class="tocnumber">4</span> <span class="toctext">Hierba Luisa</span></a>
# Hierba Luisa
# <a href="#Hierbabuena"><span class="tocnumber">5</span> <span class="toctext">Hierbabuena</span></a>
# Hierbabuena
# <a href="#Hinojo"><span class="tocnumber">6</span> <span class="toctext">Hinojo</span></a>
# Hinojo
# <a href="#Hipérico"><span class="tocnumber">7</span> <span class="toctext">Hipérico</span></a>
# Hipérico
# <a href="#Hoja_santa"><span class="tocnumber">8</span> <span class="toctext">Hoja santa</span></a>
# Hoja santa
# <a href="#Ixbut"><span class="tocnumber">9</span> <span class="toctext">Ixbut</span></a>
# Ixbut
# <a href="#Jacaranda"><span class="tocnumber">10</span> <span class="toctext">Jacaranda</span></a>
# Jacaranda
# <a href="#Jengibre"><span class="tocnumber">11</span> <span class="toctext">Jengibre</span></a>
# Jengibre
# <a href="#Jocote"><span class="tocnumber">12</span> <span class="toctext">Jocote</span></a>
# Jocote
# <a href="#Kava_kava"><span class="tocnumber">13</span> <span class="toctext">Kava kava</span></a>
# Kava kava
# <a href="#Laurel"><span class="tocnumber">14</span> <span class="toctext">Laurel</span></a>
# Laurel
# <a href="#Limón"><span class="tocnumber">15</span> <span class="toctext">Limón</span></a>
# Limón
# <a href="#Linaza"><span class="tocnumber">16</span> <span class="toctext">Linaza</span></a>
# Linaza
# <a href="#Lino_(flor_de)"><span class="tocnumber">17</span> <span class="toctext">Lino (flor de)</span></a>
# Lino (flor de)
# <a href="#Litchi"><span class="tocnumber">18</span> <span class="toctext">Litchi</span></a>
# Litchi
# <a href="#Lúpulo"><span class="tocnumber">19</span> <span class="toctext">Lúpulo</span></a>
# Lúpulo
# <a href="#Maíz,_pelo_de_elote"><span class="tocnumber">20</span> <span class="toctext">Maíz, pelo de elote</span></a>
# Maíz, pelo de elote
# <a href="#Malva"><span class="tocnumber">21</span> <span class="toctext">Malva</span></a>
# Malva
# <a href="#Manzanilla"><span class="tocnumber">22</span> <span class="toctext">Manzanilla</span></a>
# Manzanilla
# <a href="#Marrubio_blanco"><span class="tocnumber">23</span> <span class="toctext">Marrubio blanco</span></a>
# Marrubio blanco
# <a href="#Mastuerzo,_capuchina"><span class="tocnumber">24</span> <span class="toctext">Mastuerzo, capuchina</span></a>
# Mastuerzo, capuchina
# <a href="#Mercadela,_caléndula"><span class="tocnumber">25</span> <span class="toctext">Mercadela, caléndula</span></a>
# Mercadela, caléndula
# <a href="#Muña"><span class="tocnumber">26</span> <span class="toctext">Muña</span></a>
# Muña
# <a href="#Notas_y_referencias"><span class="tocnumber">27</span> <span class="toctext">Notas y referencias</span></a>
# Notas y referencias
# <a href="#Nogal"><span class="tocnumber">1</span> <span class="toctext">Nogal</span></a>
# Nogal
# <a href="#Nuez_vómica"><span class="tocnumber">2</span> <span class="toctext">Nuez vómica</span></a>
# Nuez vómica
# <a href="#Orégano_europeo"><span class="tocnumber">3</span> <span class="toctext">Orégano europeo</span></a>
# Orégano europeo
# <a href="#Palmera_enana"><span class="tocnumber">4</span> <span class="toctext">Palmera enana</span></a>
# Palmera enana
# <a href="#Plumajillo,_milenrama"><span class="tocnumber">5</span> <span class="toctext">Plumajillo, milenrama</span></a>
# Plumajillo, milenrama
# <a href="#Romero"><span class="tocnumber">6</span> <span class="toctext">Romero</span></a>
# Romero
# <a href="#Ruda"><span class="tocnumber">7</span> <span class="toctext">Ruda</span></a>
# Ruda
# <a href="#Sábila"><span class="tocnumber">8</span> <span class="toctext">Sábila</span></a>
# Sábila
# <a href="#Salvia_europea"><span class="tocnumber">9</span> <span class="toctext">Salvia europea</span></a>
# Salvia europea
# <a href="#Salvia_de_bolita"><span class="tocnumber">10</span> <span class="toctext">Salvia de bolita</span></a>
# Salvia de bolita
# <a href="#Santa_María"><span class="tocnumber">11</span> <span class="toctext">Santa María</span></a>
# Santa María
# <a href="#Saponaria"><span class="tocnumber">12</span> <span class="toctext">Saponaria</span></a>
# Saponaria
# <a href="#Sauco"><span class="tocnumber">13</span> <span class="toctext">Sauco</span></a>
# Sauco
# <a href="#Serpol"><span class="tocnumber">14</span> <span class="toctext">Serpol</span></a>
# Serpol
# <a href="#Usos_en_medicina_herbolaria"><span class="tocnumber">15</span> <span class="toctext">Usos en medicina herbolaria</span></a>
# Usos en medicina herbolaria
# <a href="#Usos_en_la_alimentación"><span class="tocnumber">16</span> <span class="toctext">Usos en la alimentación</span></a>
# Usos en la alimentación
# <a href="#Tomate"><span class="tocnumber">16.1</span> <span class="toctext">Tomate</span></a>
# Tomate
# <a href="#Tomate_de_árbol"><span class="tocnumber">16.2</span> <span class="toctext">Tomate de árbol</span></a>
# Tomate de árbol
# <a href="#Tomillo"><span class="tocnumber">16.3</span> <span class="toctext">Tomillo</span></a>
# Tomillo
# <a href="#Toronjil_morado,_melisa_mexicana"><span class="tocnumber">16.4</span> <span class="toctext">Toronjil morado, melisa mexicana</span></a>
# Toronjil morado, melisa mexicana
# <a href="#Tronadora,_retama"><span class="tocnumber">16.5</span> <span class="toctext">Tronadora, retama</span></a>
# Tronadora, retama
# <a href="#Topozán"><span class="tocnumber">16.6</span> <span class="toctext">Topozán</span></a>
# Topozán
# <a href="#Valeriana"><span class="tocnumber">16.7</span> <span class="toctext">Valeriana</span></a>
# Valeriana
# <a href="#Referencias"><span class="tocnumber">17</span> <span class="toctext">Referencias</span></a>
# Referencias
# ------------------- CRITERIO -------------------
# 1. Plantas medicinales(A-B)
# 2. Plantas medicinales(C)
# 3. Plantas medicinales(D-G)
# 4. Plantas medicinales(H-M)
# 5. Plantas medicinales(N-Z)
# --------------------------------------------
#
# Elige una opción (0 para salir):0
# Se termina la búsqueda

# %% [markdown]
# # Normas de entrega
#
# * Fecha tope de entrega: 25/10/2018
# * La entrega se realizará subiendo al campus virtual un notebook de Jupyter con la solución. El archivo tendrá como nombre WebScraping_GrupoX donde X será el número de grupo correspondiente.
