# %% [markdown]
# ### Práctica de Formatos de datos: XML

# %% [markdown]
# El objetivo de esta práctica es crear una aplicación que gestionará información sobre los parques y jardines públicos de Madrid. Para ello se van a utilizar dos APIS diferentes ofrecidas por el portal de datos abiertos del ayuntamiento de Madrid.
#
# En primer lugar se va a usar el catálogo "Principales parques y jardines municipales". Este catálogo ofrece una relación de los parques y zonas verdes cuya gestión corresponde al Ayuntamiento de Madrid, con datos de dirección y de localización para georeferenciarlos. El siguiente trozo de código permite recuperar el archivo xml en cuestion, y lo almacena en disco.

# %%
import urllib.request

x = urllib.request.urlopen('https://datos.madrid.es/egob/catalogo/200761-0-parques-jardines.xml')
a=x.read()
a=a.decode("utf-8")
prueba=open("Catalogo.xml","w")
prueba.write(str(a))
prueba.close()

# %% [markdown]
# __[Ejercicio 1 [5 puntos]]__
#
# Se pide mostrar al usuario un listado de los nombres de los parques que contiene el archivo con el objetivo de que elija uno de los parques y se le muestre de forma amigable(sin etiquetas) por pantalla la información asociada al parque que se encuentra en el fichero recuperado:
# Nombre del parque: atributo <NOMBRE>
# Descripción del parque: atributo <DESCRIPCION-ENTIDAD>
# Información conservación: atributo <DESCRIPCION>
# Horario: atributo <HORARIO>
# Equipamiento: atributo <EQUIPAMIENTO>
# Transporte: atributo <TRANSPORTE>
# Dirección: atributos <NOMBRE-VIA>,<CLASE-VIAL>,<NUM>,<LOCALIDAD>,<PROVINCIA>,<CODIGO-POSTAL>
# Por ejemplo si el usuario hubiera elegido el parque "Jardines de El Buen Retiro" debería mostrarse por pantalla:
#
# __Nombre del parque:__
#
# Jardines de El Buen Retiro
#
# __Descripción del parque:__
#
# Jardín Histórico Artístico creado en el siglo XVII. Es la zona verde más importante del centro urbano, tanto por su extensión como por su riqueza vegetal. La diversidad de sus trazados corresponde con las intervenciones realizadas a lo largo de sus diferentes etapas históricas. Destacan el Parterre de estilo francés; el Estanque Grande, las Rías y Lagos artificiales; el Campo Grande de estilo paisajista donde se ubican los Palacios de Velázquez y Cristal; los jardines de Cecilio Rodríguez caracterizado por sus cipreses recortados, setos de boj y pérgolas y la Rosaleda; los jardines de los Planteles formados por cuadros de bosquetes delimitados por setos y el Bosque del Recuerdo.Este parque se incluye entre las visitas recomendadas a turistas que visitan la ciudad, según la web oficial de turismo de Madrid. Limitación de acceso y reordenación de uso de vehículos a motor en los Jardines del Buen Retiro, Decreto 619 de 20 de diciembre de 2007.  Otras denominaciones: Parque del Retiro. El Retiro
#
# __Información conservación:__
#
# Conservación: Dirección General de Gestión del Agua y Zonas Verdes. Área de Gobierno de Medio Ambiente y Movilidad Superficie: 1.177.300 m2   Zona verde del Retiro: 113, 76 hectáreasViveros Estufas del Retiro: 3,23 hectáreasTalleres Estufas del Retiro: 0,74 hectáreas % Especies predominantes (nombre común) con respecto a especies principales:  Árboles.  N&ordm; total de unidades arbóreas: 19.859Platano de sombra 4%Pino piñonero 3% Arbustos. N&ordm; total de unidadesarbustivas: 7.922Madroño 3%Lauro 5%Durillo 16% Macizos arbustivos. Superficie de macizos arbustivos: 27.450 m2  Rosal 13%Abelia 15%Enebro 5%
#
# __Horario:__
#
# Horario del parque  Primavera y verano (de abril a septiembre): desde las 6 hasta las 24 h. Otoño e invierno (de octubre a marzo): desde las 6 hasta las 22 h.  Horario de las áreas caninas  Desde las 7:30 h hasta el cierre del parque.Para labores puntuales de mantenimiento o reparaciones, se cerrará parcialmente el área, permitiendo el paso por una de las dos puertas a la zona que quede libre de la actuación.Se instalarán carteles para informar de estos periodos de cierre parcial del espacio con 24 h de antelación a su comienzo.
#
# __Equipamiento: __
#
# Zonas infantiles:Zona del Pinar (Puerta del Ángel Caído)Campanillas Bajas (Puerta de España)Povar (Puerta de la Independencia)Hernani (Puerta de la Independencia)Plaza de Galicia (Puerta de Madrid)Plaza Sevilla (Puerta de América Española)Florida Park (Puerta de Reina Mercedes)Antigua Junta de Distrito (Puerta de Sainz  Baranda)Jardines de Herrero PalaciosCampo GrandeLa Cabaña (Puerta de Mariano de Cavia)Paseo Coches, a la altura del Instituto MeteorológicoZonas de mayores:Paseo Coches, a la altura de Puerta de América EspañolaPaseo Coches, a la altura del Instituto MeteorológicoZonas caninas:Entrada por Puerta de Mariano de CaviaInstalaciones deportivas:El Pinar (Puerta del Ángel Caído)Huerto Francés (Puerta del Ángel Caído)Puntos de información ambiental:Acceso por  C/ O&acute;Donnell, 1.Acceso por la Puerta del Niño Jesús. C/ Alfonso XII, junto a instalaciones deportivas.Otros:P: Viveros de Estufas - Plaza del Ángel CaídoQ: Teatro de Títeres, entrada por Plaza de la IndependenciaR: Embarcadero, entrada por Plaza de la IndependenciaS: Casita de la Cabaña, entrada por Puerta de Mariano de Cavia
#
# __Transporte:__
#
# Metro: Retiro (línea 2), Príncipe de Vergara (líneas 2 y 9), Ibiza (línea 9), Atocha (línea 1), Atocha. Renfe (línea 1)Autobuses: 1, 2, 9, 14, 15, 19, 20, 26, 28, 32, 51, 52, 61, 63, 74, 146, 152, 202, C Servicio Bicimad, para consultar la estación más cercana, acceda al mapa de geolocalización de las estaciones.
#
# __Dirección:__
#
# PLAZA INDEPENDENCIA, 7. MADRID. MADRID 28001
#
# Para facilitar la selección del parque se puede asignar a cada parque un número. Después de haber elegido un parque y habérsele mostrado la información, se le volverá a mostrar el menú de jardines por si quiere consultar otro parque. Entre las opciones del menú deberá existir una que sea para finaliza la búsqueda.
#
# Observar que no en todos los parques del fichero aparecen todos los campos de información requeridos. Por ejemplo,hay parques que no tienen horario o no tienen equipamiento.

# %%
# Ejercicio 1

from xml.etree import ElementTree
import html

def parsearDireccion(atributo):
    calle = ""
    tipo = ""
    numero= ""
    localidad = ""
    provincia = ""
    cp = "" 
    for datos in atributo:
        if datos.attrib["nombre"] == "NOMBRE-VIA":
            calle = datos.text
        elif datos.attrib["nombre"] == "CLASE-VIAL":
            tipo = datos.text
        elif datos.attrib["nombre"] == "NUM":
            numero = datos.text
        elif datos.attrib["nombre"] == "LOCALIDAD":
            localidad = datos.text
        elif datos.attrib["nombre"] == "PROVINCIA":
            provincia = datos.text
        elif datos.attrib["nombre"] == "CODIGO-POSTAL":
            cp = datos.text
        elif datos.attrib["nombre"] == "BARRIO":
            break;    
    informacion = tipo+" "+calle+", "+numero+". "+provincia+". "+localidad+" "+cp+ "\n"
    return informacion



def parsearInfoParque(atributos, tags, cabeceras):
    for atributo in atributos:
         for tag in tags:
            aux = str(atributo.attrib["nombre"])
            if (aux == tag):
                print('\033[1m',cabeceras[tag],'\033[0m', ":\n")
                if atributo.attrib["nombre"] != "LOCALIZACION":
                    print(html.unescape(atributo.text), "\n")
                else:
                    print(parsearDireccion(atributo))

def mostrarInformacion(fichero, diccionarioParques, indice, tags, cabeceras):
    contador_tag = 0
    f=open(fichero,"rt")
    arbol=ElementTree.parse(f)
    for atributos in arbol.findall("contenido/atributos"):
        if int(atributos[0].text) == diccionarioParques[indice]:
            parsearInfoParque(atributos, tags, cabeceras)
    f.close()
    
#Funcion que muestra el listado de los parques    
def mostrarListaParques(fichero, listaTags):
    diccionarioParques={}
    f=open(fichero,"rt")
    arbol=ElementTree.parse(f)
    i=1
    print("Estos son los parques encontrados en el fichero XML:")
    for parque in arbol.findall("./contenido/atributos/atributo"):
        if parque.attrib["nombre"] not in listaTags:
            listaTags.append(parque.attrib["nombre"])
        if parque.attrib["nombre"]=="ID-ENTIDAD":
            diccionarioParques[i] = int(parque.text)
        if parque.attrib["nombre"]=="NOMBRE":
            print("Parque",i, ": ", parque.text)
            i=i+1
    listaTags.remove("CONTENT-URL")
    listaTags.remove("TIPO")
    listaTags.remove("DATOSCONTACTOS")
    listaTags.remove("ID-ENTIDAD")
    print("\n")
    f.close()
    return diccionarioParques



def ejercicio1(fichero):
    listaTags = []
    diccionarioCabeceras = {"NOMBRE":"Nombre del parque", "DESCRIPCION-ENTIDAD":"Descripción del parque", "TRANSPORTE":"Transporte",
                            "DESCRIPCION":"Descripción de conservación", "ACCESIBILIDAD":"Accesibilidad", "LOCALIZACION":"Dirección",
                            "EQUIPAMIENTO":"Equipamiento", "HORARIO":"Horario"}
    diccionarioParques = mostrarListaParques(fichero, listaTags)
    print(listaTags)
    indice = -1
    while indice != 0:
        indice = input("¿De qué número de parque quiere obtener la información (0 para salir)? \t")
        if indice.isdigit():
            indice = int(indice)
            if diccionarioParques.get(indice):
                print("\n")
                mostrarInformacion(fichero, diccionarioParques, int(indice), listaTags, diccionarioCabeceras)
            elif indice != 0:
                print("Indice no válido\n")
        else:
            print("Introduce un número válido\n")
    
    print("\n", '\033[1m',"BYE!",'\033[0m', "\n")
    
ejercicio1("Catalogo.xml")
# Out:
# Estos son los parques encontrados en el fichero XML:
# Parque 1 :  Jardines Gregorio Ordóñez
# 2
# Parque 2 :  Jardines San Francisco el Grande
# 2
# Parque 3 :  Jardines de Andrés Saborit
# 2
# Parque 4 :  Jardines de El Buen Retiro
# 2
# Parque 5 :  Jardines de Gloria Fuertes
# 2
# Parque 6 :  Jardines de José Luis Jiménez Manso
# 2
# Parque 7 :  Jardines de Perón
# 2
# Parque 8 :  Jardines de Sabatini
# 2
# Parque 9 :  Jardines de San Fernando
# 2
# Parque 10 :  Jardines de la Avenida de Brasil
# 2
# Parque 11 :  Jardines de la Basílica
# 2
# Parque 12 :  Jardines de la Plaza Conde del Valle de Suchil
# 2
# Parque 13 :  Jardines de la Plaza de Chamberí
# 2
# Parque 14 :  Jardines de la Plaza de Olavide
# 2
# Parque 15 :  Jardines de la Plaza de Oriente, Lepanto y Cabo Noval
# 2
# Parque 16 :  Jardines de la Plaza de la Villa de París
# 2
# Parque 17 :  Jardines de la Vega
# 2
# Parque 18 :  Jardines de la calle Teresita González Quevedo
# 2
# Parque 19 :  Jardines de las Vistillas
# 2
# Parque 20 :  Jardines del Arquitecto Ribera
# 2
# Parque 21 :  Jardines del Descubrimiento
# 1
# Parque 22 :  Jardines del Doctor Fleming
# 2
# Parque 23 :  Jardines del Mundial. Castellana
# 2
# Parque 24 :  Jardines del Príncipe de Anglona
# 2
# Parque 25 :  Jardín Botánico de Pradolongo
# 2
# Parque 26 :  Jardín Concejal Alejandro Muñoz Revenga
# 2
# Parque 27 :  Jardín Doña Concha Piquer
# 2
# Parque 28 :  Jardín Fachada Pirámides I
# 2
# Parque 29 :  Jardín Glorieta de Azorín
# 2
# Parque 30 :  Jardín Jazmín
# 2
# Parque 31 :  Jardín Palacio O'Reilly
# 2
# Parque 32 :  Jardín de Embajadores M-30
# 2
# Parque 33 :  Jardín de Larra
# 2
# Parque 34 :  Jardín de la Colonia Congosto
# 2
# Parque 35 :  Jardín de las Bellas Artes
# 2
# Parque 36 :  Jardín del Bulevar de Peña Gorbea
# 2
# Parque 37 :  Jardín del Maestro Padilla
# 0
# Parque 38 :  Jardín del Templo de Debod
# 2
# Parque 39 :  Jardín del paseo Federico García Lorca
# 2
# Parque 40 :  Jardín el Torero
# 2
# Parque 41 :  Jardín histórico El Capricho de la Alameda Osuna
# 2
# Parque 42 :  Palacio de Cristal de la Arganzuela: Invernadero
# 2
# Parque 43 :  Parque Agustín Rodríguez Sahagún
# 2
# Parque 44 :  Parque Alcalde Jesús Pérez Quijano
# 2
# Parque 45 :  Parque Alfredo Kraus
# 2
# Parque 46 :  Parque Almansa
# 2
# Parque 47 :  Parque Aluche
# 2
# Parque 48 :  Parque Aluche - Poblados
# 2
# Parque 49 :  Parque Alzola
# 2
# Parque 50 :  Parque Antonio Pirala
# 2
# Parque 51 :  Parque Anunciación
# 2
# Parque 52 :  Parque Arquitecto Antonio Palacios
# 2
# Parque 53 :  Parque Arroyo Fontarrón
# 2
# Parque 54 :  Parque Arroyo Fresno
# 1
# Parque 55 :  Parque Arroyo Pozuelo
# 2
# Parque 56 :  Parque Arroyo de los Pinos
# 2
# Parque 57 :  Parque Avenida de Portugal
# 2
# Parque 58 :  Parque Azorín
# 2
# Parque 59 :  Parque Barrio Las Musas
# 0
# Parque 60 :  Parque Begoña
# 2
# Parque 61 :  Parque Biosaludable
# 2
# Parque 62 :  Parque Campo de la Paloma
# 2
# Parque 63 :  Parque Caramuel
# 1
# Parque 64 :  Parque Cerro Almodóvar
# 1
# Parque 65 :  Parque Cerro Peñabel
# 2
# Parque 66 :  Parque Cerro del Tío Pío
# 2
# Parque 67 :  Parque Cerro Águila
# 2
# Parque 68 :  Parque Ciudad de los Ángeles
# 2
# Parque 69 :  Parque Cuesta del Galbán
# 2
# Parque 70 :  Parque Cuña Verde de Vicálvaro. Zona A
# 2
# Parque 71 :  Parque Cuña Verde de Vicálvaro. Zona B
# 2
# Parque 72 :  Parque Cuña Verde de Vicálvaro. Zona C
# 2
# Parque 73 :  Parque Dehesa de la Villa
# 2
# Parque 74 :  Parque Duque de Ahumada
# 2
# Parque 75 :  Parque El Calero
# 2
# Parque 76 :  Parque El Cedral
# 2
# Parque 77 :  Parque El Cruce
# 2
# Parque 78 :  Parque Emir Mohamed I
# 2
# Parque 79 :  Parque Emperatriz María de Austria
# 2
# Parque 80 :  Parque Enrique Tierno Galván
# 2
# Parque 81 :  Parque Entrevías Forestal
# 2
# Parque 82 :  Parque Entrevías Urbano
# 2
# Parque 83 :  Parque Este de Valdebernardo
# 2
# Parque 84 :  Parque Eugenia de Montijo
# 2
# Parque 85 :  Parque Eva Duarte
# 2
# Parque 86 :  Parque Forestal Fuente Carrantona
# 2
# Parque 87 :  Parque Forestal Julio Alguacil Gómez
# 2
# Parque 88 :  Parque Forestal de Valdebebas-Felipe VI
# 2
# Parque 89 :  Parque Forestal de Vicálvaro
# 2
# Parque 90 :  Parque Félix Rodríguez de la Fuente
# 2
# Parque 91 :  Parque General Fanjul - Santa Margarita
# 2
# Parque 92 :  Parque Hortaleza
# 2
# Parque 93 :  Parque Huerta del Obispo.
# 2
# Parque 94 :  Parque Juan Carlos I
# 2
# Parque 95 :  Parque Juan Pablo II
# 2
# Parque 96 :  Parque La Rinconada
# 2
# Parque 97 :  Parque La Viña
# 2
# Parque 98 :  Parque Ladera de los Almendros
# 2
# Parque 99 :  Parque Lineal de Palomeras
# 2
# Parque 100 :  Parque Lineal del Manzanares (Usera - Pte de Vallecas)
# 2
# Parque 101 :  Parque Madrid Río
# 2
# Parque 102 :  Parque Martala
# 2
# Parque 103 :  Parque Martin Luther King
# 2
# Parque 104 :  Parque Meseta de Orcasitas
# 2
# Parque 105 :  Parque Mirador de Tierno Galván
# 2
# Parque 106 :  Parque Mirador de las Cárcavas
# 2
# Parque 107 :  Parque Norte
# 2
# Parque 108 :  Parque Nudo Norte de Begoña
# 2
# Parque 109 :  Parque Olof Palme
# 2
# Parque 110 :  Parque Orlando Zapata Tamayo
# 2
# Parque 111 :  Parque Paseo Muñoz Grandes
# 2
# Parque 112 :  Parque Payaso Fofó
# 2
# Parque 113 :  Parque Peñuelas
# 2
# Parque 114 :  Parque Pinar de la Elipa
# 2
# Parque 115 :  Parque Pinar del Rey
# 2
# Parque 116 :  Parque Plaza Chozas de Canales
# 2
# Parque 117 :  Parque Plaza Colonia Oroquieta
# 2
# Parque 118 :  Parque Plaza de España
# 2
# Parque 119 :  Parque Quinta de los Molinos
# 2
# Parque 120 :  Parque Ramírez de Prado
# 2
# Parque 121 :  Parque Roma
# 2
# Parque 122 :  Parque Salvador de Madariaga
# 2
# Parque 123 :  Parque San Blas. El Paraíso
# 2
# Parque 124 :  Parque San José de Calasanz
# 2
# Parque 125 :  Parque San Juan Bautista
# 2
# Parque 126 :  Parque Sancho Dávila
# 2
# Parque 127 :  Parque Santa Eugenia
# 2
# Parque 128 :  Parque Santa Rita
# 2
# Parque 129 :  Parque Segura
# 2
# Parque 130 :  Parque Soto de Entrevías
# 2
# Parque 131 :  Parque Urpisa
# 2
# Parque 132 :  Parque Valdebernardo Este
# 2
# Parque 133 :  Parque Valle de Enmedio
# 2
# Parque 134 :  Parque Vallecas Villa
# 2
# Parque 135 :  Parque Vandel
# 2
# Parque 136 :  Parque Virgen de la Esperanza
# 2
# Parque 137 :  Parque de Alfonso XIII
# 2
# Parque 138 :  Parque de Amos Acero
# 2
# Parque 139 :  Parque de Ana Tutor
# 2
# Parque 140 :  Parque de Arriaga
# 0
# Parque 141 :  Parque de Atenas
# 2
# Parque 142 :  Parque de Berlín
# 1
# Parque 143 :  Parque de Breogán
# 2
# Parque 144 :  Parque de Canillejas
# 2
# Parque 145 :  Parque de Comillas
# 2
# Parque 146 :  Parque de Darwin
# 2
# Parque 147 :  Parque de Enrique Herreros
# 2
# Parque 148 :  Parque de Francos Rodríguez
# 2
# Parque 149 :  Parque de Fuencarral
# 2
# Parque 150 :  Parque de Fuentechica
# 2
# Parque 151 :  Parque de Fuentelarreina
# 2
# Parque 152 :  Parque de Gabriela Mistral
# 2
# Parque 153 :  Parque de Isabel Clara Eugenia
# 2
# Parque 154 :  Parque de Juan XXIII
# 2
# Parque 155 :  Parque de Las Cruces
# 2
# Parque 156 :  Parque de Malmoe
# 0
# Parque 157 :  Parque de Manoteras
# 0
# Parque 158 :  Parque de Pan Bendito
# 2
# Parque 159 :  Parque de Peñagrande
# 2
# Parque 160 :  Parque de Pinar de Barajas
# 2
# Parque 161 :  Parque de Plata y Castañar
# 2
# Parque 162 :  Parque de Pradolongo
# 2
# Parque 163 :  Parque de Rafael Finat
# 2
# Parque 164 :  Parque de Salvador Allende
# 2
# Parque 165 :  Parque de San Isidro
# 2
# Parque 166 :  Parque de Santa Ana
# 2
# Parque 167 :  Parque de Villa Rosa-Paco Caño
# 2
# Parque 168 :  Parque de la Alcazaba
# 2
# Parque 169 :  Parque de la Almudena
# 2
# Parque 170 :  Parque de la Amistad
# 2
# Parque 171 :  Parque de la Bombilla
# 2
# Parque 172 :  Parque de la Casa de Campo
# 2
# Parque 173 :  Parque de la Cuña Verde de Latina
# 2
# Parque 174 :  Parque de la Cuña Verde de O´Donnell
# 2
# Parque 175 :  Parque de la Dehesa Boyal
# 2
# Parque 176 :  Parque de la Gavia
# 2
# Parque 177 :  Parque de la Maceta
# 2
# Parque 178 :  Parque de la Supermanzana
# 2
# Parque 179 :  Parque de la Ventilla
# 2
# Parque 180 :  Parque de la Vicalvarada
# 2
# Parque 181 :  Parque de las Avenidas
# 2
# Parque 182 :  Parque de las Delicias
# 2
# Parque 183 :  Parque de los Llanos
# 2
# Parque 184 :  Parque de los Tilos
# 2
# Parque 185 :  Parque del Bronce
# 2
# Parque 186 :  Parque del Espinillo
# 2
# Parque 187 :  Parque del Museo del Prado
# 2
# Parque 188 :  Parque del Oeste
# 2
# Parque 189 :  Parque del Pueblo del Pardo
# 2
# Parque 190 :  Pinar Santa Eugenia
# 2
# Parque 191 :  Plaza Mayor de Barajas
# 2
# Parque 192 :  Plaza de Murillo
# 2
# Parque 193 :  Plaza de la Lealtad
# 2
# Parque 194 :  Quinta de Torre Arias
# 2
# Parque 195 :  Quinta de la Fuente del Berro
# 2
# Parque 196 :  Rosaleda de Madrid. Parque del Oeste
# 2
# Parque 197 :  Vivero Estufas de El Retiro
# 0
# Parque 198 :  Vivero de la Casa de Campo
# 2
# Parque 199 :  Vivero municipal de Migas Calientes
# 0
# Parque 200 :  Zona verde C/ Fresnedillas
# 2
# Parque 201 :  Área Forestal de Tres Cantos
# 2
#
#
# ['NOMBRE', 'DESCRIPCION-ENTIDAD', 'TRANSPORTE', 'DESCRIPCION', 'ACCESIBILIDAD', 'LOCALIZACION', 'EQUIPAMIENTO', 'HORARIO']

# %% [markdown]
#  __[Ejercicio 2 [5 puntos]]__
#
# Este ejercicio se pide crear un buscador sobre la información recuperada, de forma que el usuario podrá buscar parques por diferentes criterios:
#
#  * Accesibilidad
#
#  * Nombre
#
#  * Barrio
#
#  * Distrito
#
# Como resultado debería mostrarse un listado de todos los parques que cumplen las condiciones impuestas por el usuario. Se mostrará de cada parque la misma información que en el caso anterior.  En caso de no existir un parque con las condiciones dada, se mostrará un mensaje informativo.
#
# Observar que habrá que preguntar al usuario por cada uno de los criterios, y éste tendrá que seleccionar un valor por cada criterio o no seleccionarlo. Después de lista la información habérsele mostrado la información, se le volverá a preguntar si quiere seguir buscando. Entre las opciones del menú deberá existir una que sea para finaliza la búsqueda.

# %% [markdown]
# Normas de entrega
#
#    * Fecha tope de entrega: 10/10/2018
#    * La entrega se realizará subiendo al campus virtual un notebook de Jupyter con la solución. El archivo tendrá como nombre FormatosII_GrupoX donde X será el número de grupo correspondiente.

# %%
# Ejercicio 2

from xml.etree import ElementTree
import html

#Funcion auxiliar que devuelve en el parametro lista la lista actualizada con todos los valores que toma el atributo
#Dentro de la ruta especificada para el arbol del XML
def devuelveListaValores(lista, atributo, arbol, ruta):
    for parque in arbol.findall(ruta):
        if parque.attrib["nombre"]==atributo:
            if parque.text not in lista:
                lista.append(parque.text)


def pedirAccesibilidad(fichero):
    iniRango = None
    finRango = None
    f=open(fichero,"rt")
    arbol=ElementTree.parse(f)
    listaAccesibilidad = []
    devuelveListaValores(listaAccesibilidad, "ACCESIBILIDAD", arbol, "./contenido/atributos/atributo")
    f.close()
    print("Los valores para el campo accesibilidad del xml son: ", listaAccesibilidad)

    cadena = "Introduzca accesibilidad (-1 para ningun valor): "
    accesibilidad = input(cadena)
    if accesibilidad.lstrip("-").isdigit() and int(accesibilidad) == -1:        
        print("No se asigna valor para este criterio de búsqueda\n")
        accesibilidad = None
    elif accesibilidad not in listaAccesibilidad:
        accesibilidad = None
        print("La accesibilidad elegida no se encuentra en la lista, no se asigna valor para este criterio de búsqueda\n")
    else:
        print("El criterio para el campo ACCESIBILIDAD es:", accesibilidad,"\n")
    return accesibilidad
            

def pedirNombre(fichero):
    print("\nLos nombres de los parques encontrados en el fichero son los siguientes\n")
    f=open(fichero,"rt")
    arbol=ElementTree.parse(f)
    listaNombres = []
    devuelveListaValores(listaNombres, "NOMBRE", arbol, "./contenido/atributos/atributo")
    f.close()
    print("Los nombres encontrados dentro del xml son: ",listaNombres)
    nombre = input("Introduzca nombre del parque (-1 para ningun valor)\n")
    if nombre.lstrip("-").isdigit() and int(nombre) == -1:
        nombre = None
        print("No se asigna valor para este criterio de búsqueda\n")
    elif nombre not in listaNombres:
        nombre = None
        print("El nombre introducido no se encuentra en la lista, no se asigna valor para este criterio de búsqueda\n")
    else:
        print("El criterio para el campo NOMBRE es:", nombre,"\n")
    return nombre
    
#Funcion para pedir el criterio de barrio que muestra la lista con los distintos barrios del XML
def pedirBarrio(fichero):
    print("\n", '\033[1m',"Por barrio",'\033[0m', "\n")
    listaBarrios = []
    f=open(fichero,"rt")
    arbol=ElementTree.parse(f)
    devuelveListaValores(listaBarrios, "BARRIO", arbol, "./contenido/atributos/atributo/atributo")
    f.close()
    print("Los barrios encontrados en el xml son: ", listaBarrios)
    barrio = input("Introduzca nombre del barrio (-1 para ningun valor)\n")
    
    if barrio.lstrip("-").isdigit() and int(barrio) == -1:
        barrio = None
        print("No se asigna valor para este criterio de búsqueda\n")
    elif barrio not in listaBarrios:
        barrio = None
        print("El barrio introducido no se encuentra en la lista, no se asigna valor para este criterio de búsqueda\n")
    else:
        print("El criterio para el campo BARRIO es:", barrio, "\n")
    return barrio
    

#Funcion para pedir el criterio de distrito que muestra la lista con los distintos distritos del XML
def pedirDistrito(fichero):
    print("\n", '\033[1m',"Por distrito",'\033[0m', "\n")
    listaDistritos = []
    f=open(fichero,"rt")
    arbol=ElementTree.parse(f)
    devuelveListaValores(listaDistritos, "DISTRITO", arbol, "./contenido/atributos/atributo/atributo")
    f.close()
    print("Los distritos encontrados en el xml son: ", listaDistritos)
    distrito = input("Introduzca nombre del distrito (-1 para ningun valor)\n")
    
    if distrito.lstrip("-").isdigit() and int(distrito)==-1:
        distrito = None
        print("No se asigna valor para este criterio de búsqueda\n")
    elif distrito not in listaDistritos:
        distrito = None
        print("El distrito introducido no se encuentra en la lista, no se asigna valor para este criterio de búsqueda\n")
    else:
        print("El criterio para el campo DISTRITO es:", distrito,"\n")
    return distrito


#Funcion para parsear la direccion de un parque
def parsearDireccion(atributo):
    calle = ""
    tipo = ""
    numero= ""
    localidad = ""
    provincia = ""
    cp = "" 
    for datos in atributo:
        if datos.attrib["nombre"] == "NOMBRE-VIA":
            calle = datos.text
        elif datos.attrib["nombre"] == "CLASE-VIAL":
            tipo = datos.text
        elif datos.attrib["nombre"] == "NUM":
            numero = datos.text
        elif datos.attrib["nombre"] == "LOCALIDAD":
            localidad = datos.text
        elif datos.attrib["nombre"] == "PROVINCIA":
            provincia = datos.text
        elif datos.attrib["nombre"] == "CODIGO-POSTAL":
            cp = datos.text
        elif datos.attrib["nombre"] == "BARRIO":
            break;    
    informacion = tipo+" "+calle+", "+numero+". "+provincia+". "+localidad+" "+cp+ "\n"
    return informacion


#Funcion para escribir la informacion de un parque
def escribirInformacionParque(parque):
    cabeceras = {"NOMBRE":"Nombre del parque", "DESCRIPCION-ENTIDAD":"Descripción del parque", "TRANSPORTE":"Transporte",
                            "DESCRIPCION":"Descripción de conservación", "ACCESIBILIDAD":"Accesibilidad", "LOCALIZACION":"Dirección",
                            "EQUIPAMIENTO":"Equipamiento", "HORARIO":"Horario"}
    tags = ['NOMBRE', 'DESCRIPCION-ENTIDAD', 'TRANSPORTE', 'DESCRIPCION', 'ACCESIBILIDAD', 'LOCALIZACION', 'EQUIPAMIENTO', 'HORARIO']
    
    print("\t  ------------------------------------ \n")
    for atributo in parque:
         for tag in tags:
            aux = str(atributo.attrib["nombre"])
            if (aux == tag):
                print('\033[1m',cabeceras[tag],'\033[0m', ":\n")
                if atributo.attrib["nombre"] != "LOCALIZACION":
                    print(html.unescape(atributo.text), "\n")
                else:
                    print(parsearDireccion(atributo))


def compruebaBarrio(localizacion, barrio):
    
    for datos in localizacion:
        if datos.attrib["nombre"] == "BARRIO":
            if (barrio == datos.text):
                return True
            else:
                return False
                
#Funcion que comprueba si una localizacion cumple los criterios de distrito y barrio 
def compruebaDistrito(localizacion, distrito):
    
    for datos in localizacion:
        if datos.attrib["nombre"] == "DISTRITO":
            if (distrito == datos.text):
                return True
            else:
                return False

#Funcion que comprueba si el parque cumple los criterios de accesibilidad, distrito, barrio y nombre
def compruebaParque(parque, accesibilidad, distrito, barrio, nombre):
    
    #Variables boolean para marcar si cumple cada criterio, inicializadas a true si el criterio no se tiene en cuenta
    nombreCorrecto = (nombre==None)
    accesibilidadCorrecta = (accesibilidad==None)
    distritoCorrecto = (distrito==None)
    barrioCorrecto = (barrio==None)
    valido = (nombreCorrecto and accesibilidadCorrecta and distritoCorrecto and barrioCorrecto)
    
    if not valido:
        for atributo in parque:
            #Si cumple los cuatro criterios se termina la busqueda
            if (nombreCorrecto and accesibilidadCorrecta and distritoCorrecto and barrioCorrecto):
                break
            #Si el atributo actual corresponde al nombre y el criterio de nombre se tiene en cuenta, se comprueba si coinciden
            if atributo.attrib["nombre"] == "NOMBRE" and not nombreCorrecto:
                if (atributo.text == nombre):
                    nombreCorrecto = True

            #Si el atributo actual corresponde al accesibilidad y el criterio de accesibilidad se tiene en cuenta, se comprueba si coinciden
            if atributo.attrib["nombre"] == "ACCESIBILIDAD" and not accesibilidadCorrecta:
                if (atributo.text == accesibilidad):
                    accesibilidadCorrecta = True
            
            #Si el atributo actual corresponde a la localizacion y los criterios de barrio o distrito se tienen en cuenta
            #se comprueba si coinciden
            if atributo.attrib["nombre"] == "LOCALIZACION": 
                if not distritoCorrecto:
                    distritoCorrecto = compruebaDistrito(atributo,distrito)
                if not barrioCorrecto:
                    barrioCorrecto = compruebaBarrio (atributo, barrio)
    
    #Si el parque actual cumple todos los criterios, se llama a la funcion que escribe la informacion por pantalla
    if (nombreCorrecto and accesibilidadCorrecta and distritoCorrecto and barrioCorrecto):
        escribirInformacionParque(parque)


def realizarBusqueda(fichero):
    accesibilidad = None
    nombre = None
    barrio = None
    distrito = None
    listaAtributos = []
    
    accesibilidad = pedirAccesibilidad(fichero)
    
    distrito = pedirDistrito(fichero)
    
    barrio = pedirBarrio(fichero)
    
    nombre = pedirNombre(fichero)
    
    f=open(fichero,"rt")
    arbol=ElementTree.parse(f)
    for parque in arbol.findall("contenido/atributos"):
        compruebaParque(parque, accesibilidad, distrito, barrio, nombre)
    f.close()
        
        
        
def salir():
    print("\n", '\033[1m',"Fin de la búsqueda",'\033[0m', "\n")
    return 0

def ejercicio2(fichero):
    indice = -1
    while indice != 0:
        print("\n" ,Menu Busqueda\n1.- Realizar busqueda\n0.- Salir\n")
        indice = input('Escoge una: ')
        if indice.isdigit():
            indice = int(indice)
            if indice == 1:
                print("\n", '\033[1m',"Realizando búsqueda...",'\033[0m', "\n")
                realizarBusqueda(fichero)
            elif indice != 0:
                print("¡Opcion no valida!\n")
        else:
            print("¡Opcion no valida!\n")

    salir()
    
ejercicio2("Catalogo.xml")
# Out:
# Menu Busqueda
# 1.- Realizar busqueda
# 0.- Salir
#
# Escoge una: 1
#
#   Realizando búsqueda...
#
# Los valores para el campo accesibilidad del xml son:  ['2', '1', '0']
# Introduzca accesibilidad (-1 para ningun valor): -1
# No se asigna valor para este criterio de búsqueda
#
#
#   Por distrito
#
# Los distritos encontrados en el xml son:  ['SALAMANCA', 'CENTRO', 'CHAMBERI', 'RETIRO', 'CHAMARTIN', 'MORATALAZ', 'TETUAN', 'USERA', 'ARGANZUELA', 'HORTALEZA', 'VILLA DE VALLECAS', 'PUENTE DE VALLECAS', 'MONCLOA-ARAVACA', 'BARAJAS', 'VICALVARO', 'LATINA', 'CIUDAD LINEAL', 'SAN BLAS-CANILLEJAS', 'FUENCARRAL-EL PARDO', 'VILLAVERDE', 'CARABANCHEL', 'DISTRITO']
# Introduzca nombre del distrito (-1 para ningun valor)
# -1
# No se asigna valor para este criterio de búsqueda
#
#
#   Por barrio
#
# Los barrios encontrados en el xml son:  ['LISTA', 'PALACIO', 'RIOS ROSAS', 'LOS JERONIMOS', 'NUEVA ESPAÑA', 'MEDIA LEGUA', 'CUATRO CAMINOS', 'CASTILLEJOS', 'ARAPILES', 'ALMAGRO', 'TRAFALGAR', 'JUSTICIA', 'RECOLETOS', 'HISPANOAMERICA', 'PRADOLONGO', 'GAZTAMBIDE', 'IMPERIAL', 'ACACIAS', 'APOSTOL SANTIAGO', 'LEGAZPI', 'CASCO H.VALLECAS', 'EL VISO', 'SAN DIEGO', 'CASA DE CAMPO', 'MOSCARDO', 'ALAMEDA DE OSUNA', 'CHOPERA', 'VALDEACEDERAS', 'CASCO H.VICALVARO', 'PINAR DEL REY', 'CIUDAD UNIVERSITARIA', 'ALUCHE', 'LAS AGUILAS', 'ORCASITAS', 'VENTAS', 'NIÑO JESUS', 'CANILLEJAS', 'PAVONES', 'MIRASIERRA', 'PEÑA GRANDE', 'PUERTA DEL ANGEL', 'PALOMERAS BAJAS', 'ROSAS', 'VALVERDE', 'PALOMERAS SURESTE', 'NUMANCIA', 'ARAVACA', 'LOS ANGELES', 'AMBROZ', 'CONCEPCION', 'ATALAYA', 'ABRANTES', 'ENTREVIAS', 'VISTA ALEGRE', 'GUINDALERA', 'HORCAJO', 'VALDEFUENTES', 'PROSPERIDAD', 'SAN ANDRES', 'CORRALEJOS', 'PIOVERA', 'MARROQUINA', 'ADELFAS', 'DELICIAS', 'LA PAZ', 'ZOFIO', 'CANILLAS', 'LOS ROSALES', 'ARGUELLES', 'EL SALVADOR', 'ESTRELLA', 'SAN PASCUAL', 'HELLIN', 'SAN JUAN BAUTISTA', 'FUENTE DEL BERRO', 'SANTA EUGENIA', 'PUERTA BONITA', 'PUEBLO NUEVO', 'CIUDAD JARDIN', 'COMILLAS', 'FONTARRON', 'VALLEHERMOSO', 'BUENAVISTA', 'SAN ISIDRO', 'EL PILAR', 'LUCERO', 'SAN CRISTOBAL', 'ALMENARA', 'EL PARDO', 'CASCO H.BARAJAS', 'FUENTELARREINA']
# Introduzca nombre del barrio (-1 para ningun valor)
# LISTA
# El criterio para el campo BARRIO es: LISTA
#
#
# Los nombres de los parques encontrados en el fichero son los siguientes
#
# Los nombres encontrados dentro del xml son:  ['Jardines Gregorio Ordóñez', 'Jardines San Francisco el Grande', 'Jardines de Andrés Saborit', 'Jardines de El Buen Retiro', 'Jardines de Gloria Fuertes', 'Jardines de José Luis Jiménez Manso', 'Jardines de Perón', 'Jardines de Sabatini', 'Jardines de San Fernando', 'Jardines de la Avenida de Brasil', 'Jardines de la Basílica', 'Jardines de la Plaza Conde del Valle de Suchil', 'Jardines de la Plaza de Chamberí', 'Jardines de la Plaza de Olavide', 'Jardines de la Plaza de Oriente, Lepanto y Cabo Noval', 'Jardines de la Plaza de la Villa de París', 'Jardines de la Vega', 'Jardines de la calle Teresita González Quevedo', 'Jardines de las Vistillas', 'Jardines del Arquitecto Ribera', 'Jardines del Descubrimiento', 'Jardines del Doctor Fleming', 'Jardines del Mundial. Castellana', 'Jardines del Príncipe de Anglona', 'Jardín Botánico de Pradolongo', 'Jardín Concejal Alejandro Muñoz Revenga', 'Jardín Doña Concha Piquer', 'Jardín Fachada Pirámides I', 'Jardín Glorieta de Azorín', 'Jardín Jazmín', "Jardín Palacio O'Reilly", 'Jardín de Embajadores M-30', 'Jardín de Larra', 'Jardín de la Colonia Congosto', 'Jardín de las Bellas Artes', 'Jardín del Bulevar de Peña Gorbea', 'Jardín del Maestro Padilla', 'Jardín del Templo de Debod', 'Jardín del paseo Federico García Lorca', 'Jardín el Torero', 'Jardín histórico El Capricho de la Alameda Osuna', 'Palacio de Cristal de la Arganzuela: Invernadero', 'Parque Agustín Rodríguez Sahagún', 'Parque Alcalde Jesús Pérez Quijano', 'Parque Alfredo Kraus', 'Parque Almansa', 'Parque Aluche', 'Parque Aluche - Poblados', 'Parque Alzola', 'Parque Antonio Pirala', 'Parque Anunciación', 'Parque Arquitecto Antonio Palacios', 'Parque Arroyo Fontarrón', 'Parque Arroyo Fresno', 'Parque Arroyo Pozuelo', 'Parque Arroyo de los Pinos', 'Parque Avenida de Portugal', 'Parque Azorín', 'Parque Barrio Las Musas', 'Parque Begoña', 'Parque Biosaludable', 'Parque Campo de la Paloma', 'Parque Caramuel', 'Parque Cerro Almodóvar', 'Parque Cerro Peñabel', 'Parque Cerro del Tío Pío', 'Parque Cerro Águila', 'Parque Ciudad de los Ángeles', 'Parque Cuesta del Galbán', 'Parque Cuña Verde de Vicálvaro. Zona A', 'Parque Cuña Verde de Vicálvaro. Zona B', 'Parque Cuña Verde de Vicálvaro. Zona C', 'Parque Dehesa de la Villa', 'Parque Duque de Ahumada', 'Parque El Calero', 'Parque El Cedral', 'Parque El Cruce', 'Parque Emir Mohamed I', 'Parque Emperatriz María de Austria', 'Parque Enrique Tierno Galván', 'Parque Entrevías Forestal', 'Parque Entrevías Urbano', 'Parque Este de Valdebernardo', 'Parque Eugenia de Montijo', 'Parque Eva Duarte', 'Parque Forestal Fuente Carrantona', 'Parque Forestal Julio Alguacil Gómez', 'Parque Forestal de Valdebebas-Felipe VI', 'Parque Forestal de Vicálvaro', 'Parque Félix Rodríguez de la Fuente', 'Parque General Fanjul - Santa Margarita', 'Parque Hortaleza', 'Parque Huerta del Obispo.', 'Parque Juan Carlos I', 'Parque Juan Pablo II', 'Parque La Rinconada', 'Parque La Viña', 'Parque Ladera de los Almendros', 'Parque Lineal de Palomeras', 'Parque Lineal del Manzanares (Usera - Pte de Vallecas)', 'Parque Madrid Río', 'Parque Martala', 'Parque Martin Luther King', 'Parque Meseta de Orcasitas', 'Parque Mirador de Tierno Galván', 'Parque Mirador de las Cárcavas', 'Parque Norte', 'Parque Nudo Norte de Begoña', 'Parque Olof Palme', 'Parque Orlando Zapata Tamayo', 'Parque Paseo Muñoz Grandes', 'Parque Payaso Fofó', 'Parque Peñuelas', 'Parque Pinar de la Elipa', 'Parque Pinar del Rey', 'Parque Plaza Chozas de Canales', 'Parque Plaza Colonia Oroquieta', 'Parque Plaza de España', 'Parque Quinta de los Molinos', 'Parque Ramírez de Prado', 'Parque Roma', 'Parque Salvador de Madariaga', 'Parque San Blas. El Paraíso', 'Parque San José de Calasanz', 'Parque San Juan Bautista', 'Parque Sancho Dávila', 'Parque Santa Eugenia', 'Parque Santa Rita', 'Parque Segura', 'Parque Soto de Entrevías', 'Parque Urpisa', 'Parque Valdebernardo Este', 'Parque Valle de Enmedio', 'Parque Vallecas Vill ...
# Introduzca nombre del parque (-1 para ningun valor)
# -1
# No se asigna valor para este criterio de búsqueda
#
# 	  ------------------------------------
#
#  Nombre del parque  :
#
# Jardines Gregorio Ordóñez
#
#  Descripción del parque  :
#
# Jardines en memoria de Gregorio Ordóñez. Este cuidado jardín presenta dos amplias zonas infantiles, para diversión de los pequeños y posee un pequeño estanque en el centro del mismo rodeado de distintas especies de palmeras.
#
#  Transporte  :
#
# Metro: Núñez de Balboa (líneas 5 y 9)Bus: 1, 29, 52, 74 Servicio Bicimad, para consultar la estación más cercana, acceda al mapa de geolocalización de las estaciones.
#
#  Descripción de conservación  :
#
# Conservación: Dirección General de Gestión del Agua y Zonas Verdes. Área de Gobierno de Medio Ambiente y Movilidad Superficie: 3.975 m2     % Especies predominantes (nombre común) con respecto a especies principales:  Árboles. Nº total de unidades arbóreas: 120Ciruelo rojo 53%Plátano de sombra 20%Liquidambar 11%Cinamomo 9% Arbustos. Nº total de unidades arbustivas: 49Palmito 78%Palmito de la China 22% Macizos arbustivos. Superficie de macizos arbustivos: 32 m2  Rosas 50%Madroño 28%
#
#  Accesibilidad  :
#
# 2
#
#  Dirección  :
#
# CALLE PRINCIPE DE VERGARA, 68. MADRID. MADRID 28006
#
#
# Menu Busqueda
# 1.- Realizar busqueda
# 0.- Salir
# Escoge una: 0
#
#   Fin de la búsqueda
